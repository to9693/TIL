# %%
print('hello world')
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print('''hihihihihihihih''')
# Out:
# hihihihihihihih

# %%
print('Hello World'
      'Hello World'
      'Hello World')
# Out:
# Hello WorldHello WorldHello World

# %%
print('Hello World' *3)
# Out:
# Hello WorldHello WorldHello World

# %%
a = 10
b = 3.5
c = 'sogang'

# %%
number = 20162345
score = 90
python_score= 95

# %%
math-score= 90
# Out:
#   File "<ipython-input-11-577d346e8396>", line 1
#     math-score= 90
#                   ^
# SyntaxError: can't assign to operator

# %%
math1 = 80
1math = 80
# Out:
#   File "<ipython-input-12-d6d43d2c5023>", line 2
#     1math = 80
#         ^
# SyntaxError: invalid syntax

# %%
학생수 = 50

# %%
print(score)
# Out:
# 90

# %%
print(학생수)
# Out:
# 50

# %%
a = 10; b = 20; c=30

# %%
print(a,b,c)
# Out:
# 10 20 30

# %%
print('안녕! 나는 지구인이야. 나는 다리가 4개 있어')
# Out:
# 안녕! 나는 지구인이야. 나는 다리가 4개 있어

# %%
print('안녕! 나는', '지구인','이야. 나는 다리가', 4,'개 있어')
# Out:
# 안녕! 나는 지구인 이야. 나는 다리가 4 개 있어

# %%
identity = '지구인'
number_of_legs=4
print('안녕! 나는', identity, '이야. 나는 다리가', number_of_legs, '개가 있어')
# Out:
# 안녕! 나는 지구인 이야. 나는 다리가 4 개가 있어

# %%
identity = '자메이카'
number_of_legs= 8
print('안녕! 나는', identity, '이야. 나는 다리가', number_of_legs, '개가 있어')
# Out:
# 안녕! 나는 자메이카 이야. 나는 다리가 8 개가 있어

# %%
season = '봄'
print('지금은', season , '입니다')
# Out:
# 지금은 봄 입니다

# %%
a = 23
type(a)
isinstance(a, int)
b = 0o23
c = 0x23
d = 0b1101

print(a,b,c,d)
# Out:
# 23 19 35 13

# %%
x = bin(10)
y = oct(10)
z = hex(20)
print (x,y,z)
# Out:
# 0b1010 0o12 0x14

# %%
a = int(5.6)
b = int(7.0)
c= int(-2.9)
d= int('15')
print(a,b,c,d)
# Out:
# 5 7 -2 15

# %%
a = 123
x= float(a)
y = str(a)
print(a,x,y)
# Out:
# 123 123.0 123

# %%
2**10000
# Out:
# ...

# %%
a = 1.5
type(a)
isinstance(a,float)
b = 2e5
print(b)
c = -2E-4
print(a, b ,c)

float('inf')
float('-inf')
# Out:
# 200000.0
# 1.5 200000.0 -0.0002
# -inf

# %%
my_name = 'python'

# %%
my_age = 25

# %%
print(my_name, '은 이제', my_age, '살')
# Out:
# python 은 이제 25 살

# %%
my_next_age = my_age + 1

# %%
print('내년에는', my_next_age, '살')
# Out:
# 내년에는 26 살

# %%
my_name = 'Python'
my_age = '25'
print(my_name, '은 이제', my_age, '살')
# Out:
# Python 은 이제 25 살

# %%
my_next_age = my_age +1 
print('내년에는', my_next_age, '살')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-b8ea0b312684> in <module>
# ----> 1 my_next_age = my_age +1
#       2 print('내년에는', my_next_age, '살')
#
# TypeError: can only concatenate str (not "int") to str

# %%
multiply = 9+9
divide = 30/5
power = 2 **10
reminder = 15 % 4

print(multiply, divide, power, reminder)
# Out:
# 18 6.0 1024 3

# %%
text = '2015' + '1991'
number = 2015 + 1991
entire = '215 + 1991'

# %%
print(text)
print(number)
print(entire)
# Out:
# 20151991
# 4006
# 215 + 1991

# %%
five4 = 5 *1
five5 = 5 *1.0

print(five4)
print(five5)
# Out:
# 5
# 5.0

# %%
print(6/5)
print(10/5)
# Out:
# 1.2
# 2.0

# %%
print(6 % 5)
print(10 % 5)
# Out:
# 1
# 0

# %%
div1 = 6/5
div2 = 6//5

# %%
print(div1)
print(div2)
# Out:
# 1.2
# 1

# %%
a = 6
b = 5
print(a ==b * (a//b) + (a%b))
# Out:
# True

# %%
print(int(5.0))
print(float(5))
print(5* 1.0)
# Out:
# 5
# 5.0
# 5.0

# %%
a = 21
b = 5

Sum = a + b
Multiply = a*b
divde = a /b
Remainder = a%b
power = a//b

print(Sum, Multiply, divde, Remainder, power)
# Out:
# 26 105 4.2 1 4

# %%
Year = '1978'
Month = '07'
date = '07'

print(Year, '-', Month, '-', date)
# Out:
# 1978 - 07 - 07

# %% [markdown]
# 반올림(round), 올림(ceil), 내림(floor)

# %%
round(1.2)
# Out:
# 1

# %%
import math

# %%
math.ceil(1.2)
# Out:
# 2

# %%
math.floor(1.9)
# Out:
# 1

# %%
a = 1
a < 0
# Out:
# False

# %%
a > 0
# Out:
# True

# %%
a ==2
# Out:
# False

# %%
a ==1
# Out:
# True

# %%
b = 'True'
c = 'False'
print(b,c)
# Out:
# True False

# %% [markdown]
# a = 3 +5j
# b = 10 -2J
# c = a + b
# print(c)

# %%
a= 3 +5j
b =10 -2J
c = a+b
print(c)
# Out:
# (13+3j)

# %%
a.real
# Out:
# 3.0

# %%
a.imag
# Out:
# 5.0

# %%
b.conjugate()
# Out:
# (10+2j)

# %%
a.conjugate()
# Out:
# (3-5j)
